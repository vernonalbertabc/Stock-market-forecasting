# %% [markdown]
# # Forecasting of Apple stock from 1st December to 15th December 2020
#
# ### Forecasting methods used
# 1. ARIMA
# 2. SARIMA
# 3. Vector autoregression

# %% [markdown]
# ## References
#
# 1. https://www.machinelearningplus.com/time-series/vector-autoregression-examples-python/
# 2. https://techrando.com/2019/07/19/analyzing-electricity-price-time-series-data-using-python-time-series-decomposition-and-price-forecasting-using-a-vector-autoregression-var-model/
# 3. https://github.com/ritvikmath/Time-Series-Analysis

# %% [markdown]
# ## Libraries

# %%
import yfinance as yf

import pandas as pd

from statsmodels.graphics.tsaplots import plot_pacf,plot_acf
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.api import VAR

import matplotlib.pyplot as plt
# %matplotlib inline

from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

from sklearn.metrics import mean_squared_error

from scipy.stats import pearsonr

import numpy as np

# %% [markdown]
# ## Get Data

# %%
#define the ticker symbol
tickerSymbol = 'aapl'

# %%
#get data on this ticker
tickerData = yf.Ticker(tickerSymbol)

#get the historical prices for this ticker
tickerDf = tickerData.history(interval='1d', start='2017-1-1', end='2020-12-30')

# %%
priceData = tickerDf.Open

priceData = priceData.asfreq(pd.infer_freq(priceData.index))

print(priceData)
# Out:
# Date
# 2017-01-03     27.330766
# 2017-01-04     27.342568
# 2017-01-05     27.359092
# 2017-01-06     27.562064
# 2017-01-07           NaN
#                  ...
# 2020-12-25           NaN
# 2020-12-26           NaN
# 2020-12-27           NaN
# 2020-12-28    133.563211
# 2020-12-29    137.610278
# Freq: D, Name: Open, Length: 1457, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(priceData)
for year in range(priceData.index[0].year, priceData.index[-1].year+1):
    plt.axvline(datetime(year,1,1), color='k', linestyle='--', alpha=0.2)
plt.title("%s Price Data"%tickerSymbol, fontsize=20)
# Out:
# Text(0.5, 1.0, 'aapl Price Data')

# %% [markdown]
# ## Data cleaning and exploratory analysis
# - Data is not stationary
# - Missing data can be filled with previous available values

# %%
priceData.ffill(inplace=True)

# %%
# Differencing to make values stationary

priceDiffData = priceData.diff(1)[1:]
plt.plot(priceDiffData)

# %%
print(priceData)
# Out:
# Date
# 2017-01-03     27.330766
# 2017-01-04     27.342568
# 2017-01-05     27.359092
# 2017-01-06     27.562064
# 2017-01-07     27.562064
#                  ...
# 2020-12-25    130.901713
# 2020-12-26    130.901713
# 2020-12-27    130.901713
# 2020-12-28    133.563211
# 2020-12-29    137.610278
# Freq: D, Name: Open, Length: 1457, dtype: float64

# %%
data_st = pd.concat([priceDiffData, priceDiffData.rolling(30).agg(['mean', np.std])], axis=1)

data_st.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# - Almost constant mean and standard deviation with slight changes from 2020 owing to the pandemic
# - Let's use Dicky fuller test to determine if time series is stationary

# %%
result = adfuller(data_st['Open'])

print('p-value: %f' % result[1])

if result[1] <= 0.05:
    print("Data is stationary")
else:
    print("Data is not stationary")
# Out:
# p-value: 0.000000
# Data is stationary

# %%
std_year = data_st.groupby(data_st.index.year).std()
print(std_year)
# Out:
#           Open      mean       std
# Date
# 2017  0.350991  0.065623  0.116545
# 2018  0.673883  0.127862  0.223055
# 2019  0.592840  0.118056  0.133085
# 2020  2.263783  0.338617  0.917962

# %% [markdown]
# - High volatility of in the year 2020 owing to the uncertainity of business situation due to the pandemic

# %%
plot_pacf(data_st['Open'],lags=30)
plt.show()

# %% [markdown]
# - Direct Correlation till 8th week

# %%
plot_acf(data_st['Open'],lags=30)
plt.show()

# %% [markdown]
# - Indirect and direct correlation till 8th week

# %% [markdown]
# ### ARIMA model forecasting

# %%
train_end = datetime(2020,12,1)
test_end = datetime(2020,12,15)

train = priceData[:train_end]
test  = priceData[train_end:test_end]

model = ARIMA(train, order=(15,1,15))

# %%
model_fit = model.fit()

# %%
#summary of the model
print(model_fit.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                 D.Open   No. Observations:                 1428
# Model:               ARIMA(15, 1, 15)   Log Likelihood               -2234.811
# Method:                       css-mle   S.D. of innovations              1.150
# Date:                Sat, 15 May 2021   AIC                           4533.622
# Time:                        21:40:55   BIC                           4702.071
# Sample:                    01-04-2017   HQIC                          4596.530
#                          - 12-01-2020
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.0639      0.028      2.260      0.024       0.008       0.119
# ar.L1.D.Open      0.0797        nan        nan        nan         nan         nan
# ar.L2.D.Open      0.3936        nan        nan        nan         nan         nan
# ar.L3.D.Open      0.3653        nan        nan        nan         nan         nan
# ar.L4.D.Open      0.0846        nan        nan        nan         nan         nan
# ar.L5.D.Open      0.1138        nan        nan        nan         nan         nan
# ar.L6.D.Open     -0.5492        nan        nan        nan         nan         nan
# ar.L7.D.Open      0.0428        nan        nan        nan         nan         nan
# ar.L8.D.Open      0.1938        nan        nan        nan         nan         nan
# ar.L9.D.Open      0.2725      0.221      1.234      0.217      -0.160       0.705
# ar.L10.D.Open     0.1846        nan        nan        nan         nan         nan
# ar.L11.D.Open     0.3487        nan        nan        nan         nan         nan
# ar.L12.D.Open    -0.7919        nan        nan        nan         nan         nan
# ar.L13.D.Open    -0.2478        nan        nan        nan         nan         nan
# ar.L14.D.Open     0.0815      0.321      0.254      0.800      -0.548       0.711
# ar.L15.D.Open    -0.0293      0.292     -0.100      0.920      -0.601       0.542
# ma.L1.D.Open     -0.1733        nan        nan        nan         nan         nan
# ma.L2.D.Open     -0.4772        nan        nan        nan         nan         nan
# ma.L3.D.Open     -0.2520        nan        nan        nan         nan         nan
# ma.L4.D.Open     -0.0317        nan        nan        nan         nan         nan
# ma.L5.D.Open     -0.1334        nan        nan        nan         nan         nan
# ma.L6.D.Open      0.5741        nan        nan        nan         nan         nan
# ma.L7.D.Open     -0.0725        nan        nan        nan         nan         nan
# ma.L8.D.Open     -0.2044        nan        nan        nan         nan         nan
# ma.L9.D.Open     -0.2180      0.266     -0.820      0.412      -0.739       0.303
# ma.L10.D.Open    -0.2220        nan        nan        nan         nan         nan
# ma.L11.D.Open    -0.3833        nan        nan        nan         nan         nan
# ma.L12.D.Open     0.9147        nan        nan        nan         nan         nan
# ma.L13.D.Open     0.2656        nan        nan        nan         nan         nan
# ma.L14.D.Open    -0.1692      0.294     -0.576      0.565      -0.745       0.407
# ma.L15.D.Open     0.0070      0.271      0.026      0.979      -0.524       0.538
#                                     Roots
# ==============================================================================
#                    Real          Imaginary           Modulus         Frequency
# ------------------------------------------------------------------------------
# AR.1             0.9965           -0.1464j            1.0072           -0.0232
# AR.2             0.9965           +0.1464j            1.0072            0.0232
# AR.3             0.8117           -0.5995j            1.0090           -0.1012
# AR.4             0.8117           +0.5995j            1.0090            0.1012
# AR.5             0.2494           -1.0019j            1.0324           -0.2112
# AR.6             0.2494           +1.0019j            1.0324            0.2112
# AR.7            -0.1975           -0.9881j            1.0077           -0.2814
# AR.8            -0.1975           +0.9881j            1.0077            0.2814
# AR.9            -0.7223           -0.6943j            1.0019           -0.3781
# AR.10           -0.7223           +0.6943j            1.0019            0.3781
# AR.11           -0.9444           -0.3487j            1.0067           -0.4437
# AR.12           -0.9444           +0.3487j            1.0067            0.4437
# AR.13           -1.8985           -0.0000j            1.8985           -0.5000
# AR.14            2.1487           -3.3477j            3.9779           -0.1592
# AR.15            2.1487           +3.3477j            3.9779            0.1592
# MA.1             0.9914           -0.1498j            1.0026           -0.0239
# MA.2             0.9914           +0.1498j            1.0026            0.0239
# MA.3             0.8053           -0.5937j            1.0005           -0.1011
# MA.4             0.8053           +0.5937j            1.0005            0.1011
# MA.5             0.2632           -0.9783j            1.0131           -0.2082
# MA.6             0.2632           +0.9783j            1.0131            0.2082
# MA.7            -0.1910           -0.9817j            1.0001           -0.2806
# MA.8            -0.1910           +0.9817j            1.0001            0.2806
# MA.9            -0.7281           -0.6864j            1.0006           -0.3797
# MA.10           -0.7281           +0.6864j            1.0006            0.3797
# MA.11           -0.9392           -0.3437j            1.0001           -0.4442
# MA.12           -0.9392           +0.3437j            1.0001            0.4442
# MA.13           -1.8306           -0.0000j            1.8306           -0.5000
# MA.14            3.3991           -0.0000j            3.3991           -0.0000
# MA.15           22.0448           -0.0000j           22.0448           -0.0000
# ------------------------------------------------------------------------------

# %%
fc, se, conf = model_fit.forecast(len(test),alpha=0.05)

# Make as pandas series
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# Plot
plt.figure(figsize=(12,5), dpi=100)
#plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
 
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print("The MAPE error is: ",mean_absolute_percentage_error(test,fc_series))
# Out:
# The MAPE error is:  1.4598905423293302

# %% [markdown]
# ## SARIMA model forecasting

# %%
priceDiff = priceData.diff(365)[1:]

print(priceDiff)
# Out:
# Date
# 2017-01-04          NaN
# 2017-01-05          NaN
# 2017-01-06          NaN
# 2017-01-07          NaN
# 2017-01-08          NaN
#                 ...
# 2020-12-25    60.531232
# 2020-12-26    58.974703
# 2020-12-27    58.974703
# 2020-12-28    61.636201
# 2020-12-29    66.093408
# Freq: D, Name: Open, Length: 1456, dtype: float64

# %%
data_st = pd.concat([priceDiff, priceDiff.rolling(30).agg(['mean', np.std])], axis=1)

data_st.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# - Constant standard deviation but not mean

# %%
# Differencing by 1 to make values stationary
priceDiffData = priceData.diff(1)[1:]
plt.plot(priceDiffData)

data_st = pd.concat([priceDiffData, priceDiffData.rolling(30).agg(['mean', np.std])], axis=1)
data_st.plot(figsize=(20,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plot_pacf(data_st['Open'],lags=77)
plt.show()

plot_acf(data_st['Open'],lags=77)
plt.show()

# %%
my_order = (2,1,3)
my_seasonal_order = (1, 0, 1, 77)
# define model

train_end = datetime(2020,12,1)
test_end = datetime(2020,12,15)

train = priceData[:train_end]
test  = priceData[train_end:test_end]

model = SARIMAX(train, order=my_order, seasonal_order=my_seasonal_order)

# %%
model_fit = model.fit()

# %%
#summary of the model
print(model_fit.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                 Open   No. Observations:                 1429
# Model:             SARIMAX(2, 1, 3)x(1, 0, [1], 77)   Log Likelihood               -2266.901
# Date:                              Sat, 15 May 2021   AIC                           4549.802
# Time:                                      21:42:12   BIC                           4591.914
# Sample:                                  01-03-2017   HQIC                          4565.529
#                                        - 12-01-2020
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.3220      0.290     -1.110      0.267      -0.891       0.247
# ar.L2         -0.1480      0.202     -0.733      0.464      -0.544       0.248
# ma.L1          0.2326      0.290      0.802      0.423      -0.336       0.801
# ma.L2          0.0215      0.184      0.117      0.907      -0.339       0.382
# ma.L3          0.0328      0.044      0.749      0.454      -0.053       0.119
# ar.S.L77      -0.2389      0.112     -2.135      0.033      -0.458      -0.020
# ma.S.L77       0.3818      0.105      3.634      0.000       0.176       0.588
# sigma2         1.3990      0.019     72.481      0.000       1.361       1.437
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):             15788.84
# Prob(Q):                              0.91   Prob(JB):                         0.00
# Heteroskedasticity (H):              20.72   Skew:                            -0.25
# Prob(H) (two-sided):                  0.00   Kurtosis:                        19.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
test = test.to_frame()

test['Pred'] = model_fit.forecast(len(test))

## Plot
plt.figure(figsize=(12,5), dpi=100)
plt.plot(test["Open"], label='actual')
plt.plot(test['Pred'], label='forecast')
plt.show()
# Out:
#                   Open        Pred
# Date
# 2020-12-01  120.624557         NaN
# 2020-12-02  121.631329  119.777023
# 2020-12-03  123.126555  118.651447
# 2020-12-04  122.209495  119.008496
# 2020-12-05  122.209495  118.969897
# 2020-12-06  122.209495  118.941492
# 2020-12-07  121.920412  118.093751
# 2020-12-08  123.973855  119.149830
# 2020-12-09  124.133338  118.947495
# 2020-12-10  120.116180  117.929671
# 2020-12-11  122.040029  118.447595
# 2020-12-12  122.040029  118.447467
# 2020-12-13  122.040029  118.447499
# 2020-12-14  122.209485  119.318028
# 2020-12-15  123.943939  119.385632

# %%
print("The MAPE error is: ",mean_absolute_percentage_error(test["Open"],test["Pred"]))
# Out:
# The MAPE error is:  2.9289958411623718

# %% [markdown]
# - Since ARIMA outperforms SARIMAX, let's use ARIMA for anomaly detection
# - Let's see if stock performance of Apple can be used to forecast stock performance of Samsung

# %% [markdown]
# ## Vector auto regression
#
# - Regression with the help of Apple's competitor Microsoft

# %%
# Get data for Microsft
tickerSymbol = 'MSFT'
tickerData = yf.Ticker(tickerSymbol)
tickerDf = tickerData.history(interval='1d', start='2017-1-1', end='2020-12-30')
NewpriceData = tickerDf.Open
NewpriceData = NewpriceData.asfreq(pd.infer_freq(priceData.index))
NewpriceData.ffill(inplace=True)

plt.figure(figsize=(10,4))
plt.plot(priceData,'-r',label='Apple stock price')
plt.plot(NewpriceData,'-b',label='Microsoft stock price')
plt.legend()
plt.show()

# %%
# Differencing to make values stationary

NewpriceDiffData = NewpriceData.diff(1)[1:]
plt.plot(NewpriceDiffData)

# %%
result = adfuller(NewpriceDiffData)

print('p-value: %f' % result[1])

if result[1] <= 0.05:
    print("Data is stationary")
else:
    print("Data is not stationary")
# Out:
# p-value: 0.000000
# Data is stationary

# %% [markdown]
# ### Getting lag through Pearson correlation

# %%
for lag in range(1, 40):
    Apple_series = priceDiffData[lag:]
    Dell_series = NewpriceDiffData[:-lag]
    print('Lag: ',lag)
    print(pearsonr(Apple_series, Dell_series))
    
    print("*********")
# Out:
# Lag:  1
# (-0.12891895090093558, 8.059558634754407e-07)
# *********
# Lag:  2
# (-0.03375048125593385, 0.1983694073439827)
# *********
# Lag:  3
# (0.06776212870456443, 0.009774111461216931)
# *********
# Lag:  4
# (0.011116245728858313, 0.6721244499860661)
# *********
# Lag:  5
# (-0.02604132647857694, 0.321549237841765)
# *********
# Lag:  6
# (-0.003896363371685828, 0.8821520200359031)
# *********
# Lag:  7
# (0.03367527686623665, 0.20014759750160285)
# *********
# Lag:  8
# (-0.03431032276748064, 0.1919427452032709)
# *********
# Lag:  9
# (-0.03605665354288549, 0.17042614362391073)
# *********
# Lag:  10
# (0.02306123665926889, 0.3808714109072774)
# *********
# Lag:  11
# (-0.018175850975025457, 0.4899548996409405)
# *********
# Lag:  12
# (0.058595938648969975, 0.02597196503069439)
# *********
# Lag:  13
# (0.01457042407236303, 0.5802400785230203)
# *********
# Lag:  14
# (-0.01305124212053737, 0.6204625283180858)
# *********
# Lag:  15
# (-0.04415902372246093, 0.0938044974222713)
# *********
# Lag:  16
# (0.005743488751518701, 0.8276140848166563)
# *********
# Lag:  17
# (-0.0015332754428421247, 0.9536586228306768)
# *********
# Lag:  18
# (-0.03665067688331824, 0.1648062004869418)
# *********
# Lag:  19
# (-0.004389698946660251, 0.8679525414217478)
# *********
# Lag:  20
# (-0.007381799282465986, 0.7798684472382595)
# *********
# Lag:  21
# (0.02763527929406312, 0.2954915865398007)
# *********
# Lag:  22
# (-0.0834099236153679, 0.0015704577797952658)
# *********
# Lag:  23
# (0.04883135050910738, 0.06460241695866889)
# *********
# Lag:  24
# (0.028967692810273518, 0.2733144761230047)
# *********
# Lag:  25
# (0.003039998993268727, 0.9085255279362502)
# *********
# Lag:  26
# (0.012673961952171856, 0.6320308925929616)
# *********
# Lag:  27
# (0.016697765475703733, 0.5282350801490345)
# *********
# Lag:  28
# (0.03731890960092742, 0.15868852703971037)
# *********
# Lag:  29
# (0.002731486753149808, 0.9178887892408246)
# *********
# Lag:  30
# (-0.0397294531065822, 0.13372932199615703)
# *********
# Lag:  31
# (-0.060977610179127416, 0.021336491122999554)
# *********
# Lag:  32
# (0.03693107711942287, 0.16365618391920606)
# *********
# Lag:  33
# (0.032228551239982625, 0.2243682612346563)
# *********
# Lag:  34
# (-0.025109561849842584, 0.34405505298971484)
# *********
# Lag:  35
# (0.01546903876953639, 0.5601323303654352)
# *********
# Lag:  36
# (-0.05277397983964188, 0.046777388034496714)
# *********
# Lag:  37
# (0.023678053820080116, 0.37277783650199897)
# *********
# Lag:  38
# (-0.04142247216323117, 0.11896979901038564)
# *********
# Lag:  39
# (-0.033125908275105316, 0.21269020003671238)
# *********

# %%
df = pd.DataFrame()
df["Apple Stock"] = priceDiffData
df["Microsoft Stock"] = NewpriceDiffData

train_end = datetime(2020,12,1)
test_end = datetime(2020,12,15)

train = df[:train_end]
test = df[train_end:test_end]

# %%
model = VAR(train)

model_fit = model.fit(maxlags=22)
model_fit.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sat, 15, May, 2021
# Time:                     21:42:13
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                    1.33972
# Nobs:                     1406.00    HQIC:                   1.12932
# Log likelihood:          -4605.69    FPE:                    2.72862
# AIC:                      1.00375    Det(Omega_mle):         2.56200
# --------------------------------------------------------------------
# Results for equation Apple Stock
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.080505         0.032711            2.461           0.014
# L1.Apple Stock             -0.026082         0.039097           -0.667           0.505
# L1.Microsoft Stock         -0.058783         0.022901           -2.567           0.010
# L2.Apple Stock             -0.152450         0.039144           -3.895           0.000
# L2.Microsoft Stock          0.046595         0.022942            2.031           0.042
# L3.Apple Stock              0.048242         0.039322            1.227           0.220
# L3.Microsoft Stock          0.007763         0.023012            0.337           0.736
# L4.Apple Stock             -0.067672         0.039340           -1.720           0.085
# L4.Microsoft Stock          0.049245         0.023006            2.140           0.032
# L5.Apple Stock              0.008824         0.039306            0.225           0.822
# L5.Microsoft Stock         -0.020257         0.023046           -0.879           0.379
# L6.Apple Stock              0.015051         0.039304            0.383           0.702
# L6.Microsoft Stock          0.005542         0.023061            0.240           0.810
# L7.Apple Stock              0.001080         0.039337            0.027           0.978
# L7.Microsoft Stock          0.001381         0.023109            0.060           0.952
# L8.Apple Stock              0.204327         0.039590            5.161           0.000
# L8.Microsoft Stock         -0.117940         0.023054           -5.116           0.000
# L9.Apple Stock              0.091991         0.040084            2.295           0.022
# L9.Microsoft Stock         -0.050761         0.023283           -2.180           0.029
# L10.Apple Stock            -0.060394         0.040104           -1.506           0.132
# L10.Microsoft Stock         0.032861         0.023308            1.410           0.159
# L11.Apple Stock            -0.049157         0.040048           -1.227           0.220
# L11.Microsoft Stock         0.007277         0.023338            0.312           0.755
# L12.Apple Stock            -0.127938         0.040051           -3.194           0.001
# L12.Microsoft Stock         0.084051         0.023337            3.602           0.000
# L13.Apple Stock             0.072837         0.040119            1.816           0.069
# L13.Microsoft Stock        -0.038567         0.023419           -1.647           0.100
# L14.Apple Stock             0.072966         0.040114            1.819           0.069
# L14.Microsoft Stock        -0.022786         0.023451           -0.972           0.331
# L15.Apple Stock            -0.075124         0.039747           -1.890           0.059
# L15.Microsoft Stock        -0.000437         0.023407           -0.019           0.985
# L16.Apple Stock             0.026280         0.039836            0.660           0.509
# L16.Microsoft Stock        -0.026746         0.023385           -1.144           0.253
# L17.Apple Stock             0.063387         0.039838            1.591           0.112
# L17.Microsoft Stock        -0.031857         0.023391           -1.362           0.173
# L18.Apple Stock             0.085832         0.039872            2.153           0.031
# L18.Microsoft Stock        -0.057015         0.023385           -2.438           0.015
# L19.Apple Stock             0.000213         0.039886            0.005           0.996
# L19.Microsoft Stock         0.011006         0.023421            0.470           0.638
# L20.Apple Stock             0.043860         0.039874            1.100           0.271
# L20.Microsoft Stock        -0.046699         0.023433           -1.993           0.046
# L21.Apple Stock             0.148509         0.039853            3.726           0.000
# L21.Microsoft Stock        -0.052337         0.023479           -2.229           0.026
# L22.Apple Stock            -0.070253         0.039818           -1.764           0.078
# L22.Microsoft Stock        -0.005147         0.023539           -0.219           0.827
# ======================================================================================
#
# Results for equation Microsoft Stock
# ======================================================================================
#                          coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------------
# const                       0.149091         0.055475            2.688           0.007
# L1.Apple Stock              0.134992         0.066305            2.036           0.042
# L1.Microsoft Stock         -0.137304         0.038838           -3.535           0.000
# L2.Apple Stock             -0.142588         0.066385           -2.148           0.032
# L2.Microsoft Stock         -0.006657         0.038908           -0.171           0.864
# L3.Apple Stock              0.097938         0.066686            1.469           0.142
# L3.Microsoft Stock         -0.010746         0.039027           -0.275           0.783
# L4.Apple Stock             -0.112688         0.066717           -1.689           0.091
# L4.Microsoft Stock          0.026374         0.039016            0.676           0.499
# L5.Apple Stock              0.047018         0.066659            0.705           0.481
# L5.Microsoft Stock         -0.062763         0.039083           -1.606           0.108
# L6.Apple Stock              0.069613         0.066656            1.044           0.296
# L6.Microsoft Stock         -0.032330         0.039109           -0.827           0.408
# L7.Apple Stock             -0.031209         0.066712           -0.468           0.640
# L7.Microsoft Stock         -0.015005         0.039190           -0.383           0.702
# L8.Apple Stock              0.128878         0.067141            1.920           0.055
# L8.Microsoft Stock         -0.115833         0.039098           -2.963           0.003
# L9.Apple Stock              0.092642         0.067979            1.363           0.173
# L9.Microsoft Stock         -0.079744         0.039485           -2.020           0.043
# L10.Apple Stock             0.018136         0.068012            0.267           0.790
# L10.Microsoft Stock        -0.000521         0.039528           -0.013           0.989
# L11.Apple Stock            -0.065073         0.067918           -0.958           0.338
# L11.Microsoft Stock         0.008033         0.039579            0.203           0.839
# L12.Apple Stock            -0.115716         0.067923           -1.704           0.088
# L12.Microsoft Stock         0.094046         0.039577            2.376           0.017
# L13.Apple Stock             0.062996         0.068038            0.926           0.355
# L13.Microsoft Stock        -0.003062         0.039717           -0.077           0.939
# L14.Apple Stock             0.083034         0.068030            1.221           0.222
# L14.Microsoft Stock        -0.014530         0.039771           -0.365           0.715
# L15.Apple Stock            -0.200591         0.067408           -2.976           0.003
# L15.Microsoft Stock        -0.009795         0.039695           -0.247           0.805
# L16.Apple Stock             0.029358         0.067559            0.435           0.664
# L16.Microsoft Stock        -0.047211         0.039658           -1.190           0.234
# L17.Apple Stock             0.106135         0.067561            1.571           0.116
# L17.Microsoft Stock        -0.062369         0.039669           -1.572           0.116
# L18.Apple Stock             0.054458         0.067619            0.805           0.421
# L18.Microsoft Stock        -0.027108         0.039658           -0.684           0.494
# L19.Apple Stock            -0.049083         0.067642           -0.726           0.468
# L19.Microsoft Stock         0.035035         0.039719            0.882           0.378
# L20.Apple Stock             0.045977         0.067623            0.680           0.497
# L20.Microsoft Stock        -0.031368         0.039740           -0.789           0.430
# L21.Apple Stock             0.145894         0.067586            2.159           0.031
# L21.Microsoft Stock         0.012340         0.039818            0.310           0.757
# L22.Apple Stock            -0.098903         0.067528           -1.465           0.143
# L22.Microsoft Stock        -0.046629         0.039920           -1.168           0.243
# ======================================================================================
#
# Correlation matrix of residuals
#                    Apple Stock  Microsoft Stock
# Apple Stock           1.000000         0.715437
# Microsoft Stock       0.715437         1.000000

# %%
# make prediction on validation
prediction = model_fit.forecast(model_fit.y, steps=len(test))
print(prediction)
# Out:
# [[-0.17310392  1.08379156]
#  [-0.91808771 -0.53703774]
#  [ 0.45725152  0.01733465]
#  [ 0.44122815  0.28590513]
#  [ 0.44078601  0.55826126]
#  [ 0.03211348  0.37691211]
#  [ 0.08637977  0.29339522]
#  [ 0.98273477  0.95904674]
#  [ 0.05001511 -0.02779518]
#  [-0.49587801 -0.16193873]
#  [-0.51017168 -0.83652065]
#  [-0.23977543 -0.12513085]
#  [ 0.50032731  0.52900144]
#  [-0.09713503  0.13099436]
#  [-0.27948892 -0.33530952]]

# %%
#converting predictions to dataframe
cols = df.columns

pred = pd.DataFrame(index=test.index,columns=cols)



for j in range(0,2):
    for i in range(0, len(prediction)):
        
        pred.iloc[i][j] = prediction[i][j]
        
print(mean_absolute_percentage_error(pred["Microsoft Stock"], test["Microsoft Stock"]))
print(mean_absolute_percentage_error(pred["Apple Stock"], test["Apple Stock"]))
# Out:
# 807.7238584582826
# 434.377380736299

# %%
append_df_org = pd.concat([train,test])
append_df_comp = pd.concat([train,pred])

# %% [markdown]
# ### Reverse the pre-processing steps

# %%
for i in range(1,len(append_df_org)):
    append_df_org.iloc[i]['Apple Stock']= append_df_org.iloc[i-1]['Apple Stock']+ \
    append_df_org.iloc[i]['Apple Stock']
    
    append_df_org.iloc[i]["Microsoft Stock"]= append_df_org.iloc[i-1]["Microsoft Stock"]+ \
    append_df_org.iloc[i]["Microsoft Stock"]

# %%
for i in range(1,len(append_df_comp)):
    append_df_comp.iloc[i]['Apple Stock']= append_df_comp.iloc[i-1]['Apple Stock']+ \
    append_df_comp.iloc[i]['Apple Stock']
    
    append_df_comp.iloc[i]["Microsoft Stock"]= append_df_comp.iloc[i-1]["Microsoft Stock"]+ \
    append_df_comp.iloc[i]["Microsoft Stock"]

# %% [markdown]
# ### Get prediction error

# %%
print("MAPE between predicted and actual Microsoft stocks: ",mean_absolute_percentage_error(append_df_org.loc[train_end:test_end]["Microsoft Stock"], append_df_comp[train_end:test_end]["Microsoft Stock"]))
print("MAPE between predicted and actual Apple stocks: ",mean_absolute_percentage_error(append_df_org.loc[train_end:test_end]["Apple Stock"], append_df_comp.loc[train_end:test_end]["Apple Stock"]))
# Out:
# MAPE between predicted and actual Microsoft stocks:  1.627510323844511
# MAPE between predicted and actual Apple stocks:  5.103816756937441

# %% [markdown]
# - Not an improvement over the ARIMA model

# %%
plt.figure(figsize=(20,5))

plt.plot(append_df_org.loc[train_end:test_end]["Microsoft Stock"], label='Actual')
plt.plot(append_df_comp[train_end:test_end]["Microsoft Stock"], label='Forecast')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(20,5))

plt.plot(append_df_org.loc[train_end:test_end]["Apple Stock"], label='Actual')
plt.plot(append_df_comp.loc[train_end:test_end]["Apple Stock"], label='Forecast')
plt.legend()
plt.show()

# %% [markdown]
# # Anomaly detection - to be contd
